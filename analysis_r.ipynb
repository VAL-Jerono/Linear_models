# %% [markdown]
# # Loan Analysis in R (CRISP-DM)
#
# This notebook rebuilds the full analysis pipeline in R, step by step.

# %% [markdown]
# ## Phase 0: Environment Setup
#
# Install packages once, then load libraries each session.

# %%
# Run once, then comment this line:
# install.packages(c("tidyverse", "caret", "GGally", "corrplot", "car", "MASS", "lmtest", "pROC", "rpart", "randomForest"))

library(tidyverse)
library(caret)
library(GGally)x
library(corrplot)
library(car)
library(MASS)
library(lmtest)
library(pROC)
library(rpart)
library(randomForest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Run once, then comment this line:
#       2 # install.packages(c("tidyverse", "caret", "GGally", "corrplot", "car", "MASS", "lmtest", "pROC", "rpart", "randomForest"))
# ----> 4 library(tidyverse)
#       5 library(caret)
#       6 library(GGally)
#
# NameError: name 'library' is not defined

# %% [markdown]
# ## Phase 1: Data Understanding
#
# Load the dataset and inspect structure, missingness, and target balance.

# %%
loan_df <- read.csv("loan_data.csv")

dim(loan_df)
str(loan_df)
summary(loan_df)
colSums(is.na(loan_df))
prop.table(table(loan_df$loan_status))

# %% [markdown]
# ## Notes
#
# Write findings after each phase before moving to modeling.
